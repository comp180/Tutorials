# %% [markdown]
# # New Assignment- Lines and Scatter Plots
#
# ## 1.) Line Plot
# Create a line plot of sin(x) and cos(x + (pi)/2) for -2(pi) < x < 2(pi) where x increases at intervals of pi/4.
#
# **x** = -6.283, -5.498, -4.712, -3.927, -3.142, -2.356, -1.571, -.7854, 0, .7854, 1.571, 2.356, 3.142, 3.927, 4.712, 5.498, 6.283
#
# **sin(x)** = 0, .70711, 1, .70711, 0, -.70711, -1, -.70711, 0, .70711, 1, .70711, 0, -.70711, -1, -.70711, 0, .
#
# **cox(x + (pi)/2)** = 0, -.70711, -1, -.70711, 0, .70711, 1, .70711, 0, -.70711, -1, -.70711, 0, .70711, 1, .70711, 0
# * Make the sin(x) graph red with width of 3 (lwd=3)
# * Make the cox(x+(pi)/2) graph green with width of 3 (lwd=3)
# * Put both lines onto the same plot

# %%
import matplotlib.pyplot as plt

x = [ -6.283, -5.498, -4.712, -3.927, -3.142, -2.356, -1.571, -.7854, 0, .7854, 1.571, 2.356, 3.142, 3.927, 4.712, 5.498, 6.283]
sin_function = [0, .70711, 1, .70711, 0, -.70711, -1, -.70711, 0, .70711, 1, .70711, 0, -.70711, -1, -.70711, 0]
cos_function = [0, -.70711, -1, -.70711, 0, .70711, 1, .70711, 0, -.70711, -1, -.70711, 0, .70711, 1, .70711, 0 ]

plt.plot(x,sin_function,marker='o',color='r',linewidth=3.0)
plt.plot(x,cos_function,marker='^',color='g',linewidth=3.0)

plt.title("Y vs. X")
plt.ylabel('Y')
plt.xlabel('X')
plt.legend(['Sin(x)','Cos(x+(pi)/2)'],loc='best')

plt.show()

# %% [markdown]
# Using the same info as above, make a subplot with 2 different graphs-
# * one graph for sin(x) and
# * one graph for cos(x+(pi)/2)

# %%
import matplotlib.pyplot as plt

x = [ -6.283, -5.498, -4.712, -3.927, -3.142, -2.356, -1.571, -.7854, 0, .7854, 1.571, 2.356, 3.142, 3.927, 4.712, 5.498, 6.283]
sin_function = [0, .70711, 1, .70711, 0, -.70711, -1, -.70711, 0, .70711, 1, .70711, 0, -.70711, -1, -.70711, 0]
cos_function = [0, -.70711, -1, -.70711, 0, .70711, 1, .70711, 0, -.70711, -1, -.70711, 0, .70711, 1, .70711, 0 ]

plt.subplot(2,2,1)
plt.plot(x,sin_function,color='r',linewidth=3.0)
plt.xlabel('Angle')
plt.ylabel('sin(x)')

plt.subplot(2,2,2)
plt.plot(x,cos_function,color='g',linewidth=3.0)
plt.xlabel('Angle')
plt.ylabel('cos(x+(pi)/2)')

plt.tight_layout()

plt.show()

# %% [markdown]
# ## 2.) Scatter Plot
# Using the following data about [winter temperatures affecting the number of days for lake ice at Lake Superior](http://resources.seattlecentral.edu/qelp/sets/053/053.htm), construct a scatter plot to display the data.
# * **Mean Temp**: 22.94, 23.02, 25.68, 19.96, 24.80, 23.98, 22.10, 20.30, 24.20, 22.74, 24.16, 24.94, 22.40, 22.14, 20.84, 25.66, 21.73, 24.49, 24.13, 22.17, 21.73, 20.41, 24.41, 23.95, 20.95, 26.71, 22.81, 23.11, 23.33, 28.83, 23.11, 21.47, 23.97, 24.75, 23.61, 23.08, 21.24, 26.63, 23.88
# * **Days of Ice**: 87, 137, 106, 97, 105, 118, 118, 136, 91, 107, 96, 114, 125, 115, 118, 82, 115, 97, 104, 146, 126, 141, 111, 123, 118, 83, 48, 118, 116, 81, 116, 123, 112, 99, 102, 118, 63, 62, 132
#
# Include a line of best fit and make sure the points on the plot are big enough (*cex*) and an appropriate shape (*pch*).

# %%
import matplotlib.pyplot as plt

#Mean temp on the x-axis
mean_temps = [22.94, 23.02, 25.68, 19.96, 24.80, 23.98, 22.10, 20.30, 24.20, 22.74, 24.16, 24.94, 22.40, 22.14, 20.84, 25.66, 21.73, 24.49, 24.13, 22.17, 21.73, 20.41, 24.41, 23.95, 20.95, 26.71, 22.81, 23.11, 23.33, 28.83, 23.11, 21.47, 23.97, 24.75, 23.61, 23.08, 21.24, 26.63, 23.88]
#Days of ice on the y-axis
days_ice = [ 87, 137, 106, 97, 105, 118, 118, 136, 91, 107, 96, 114, 125, 115, 118, 82, 115, 97, 104, 146, 126, 141, 111, 123, 118, 83, 48, 118, 116, 81, 116, 123, 112, 99, 102, 118, 63, 62, 132]

# solve for a and b
def best_fit(X, Y):
    xbar = sum(X)/len(X)
    ybar = sum(Y)/len(Y)
    n = len(X) # or len(Y)

    numer = sum([xi*yi for xi,yi in zip(X, Y)]) - n * xbar * ybar
    denum = sum([xi**2 for xi in X]) - n * xbar**2

    b = numer / denum
    a = ybar - b * xbar

    print('best fit line:\ny = {:.2f} + {:.2f}x'.format(a, b))

    return a, b

a,b = best_fit(mean_temps,days_ice)

plt.scatter(mean_temps,days_ice,facecolors='none',edgecolors='black',s=50.0)
yfit = [a+b * xi for xi in mean_temps]
plt.plot(mean_temps,yfit)

plt.xlabel('Mean Temperatures')
plt.ylabel('Days of Ice')
plt.title('Days of Ice vs. Mean Temperatures')

plt.show()
# Out:
# best fit line:
# y = 225.45 + -5.04x
